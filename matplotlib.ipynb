# %% [markdown]
# # Quitor - Introduction to Matplotlib

# %% [markdown]
# ### Imports

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data

# %% [markdown]
# ---

# %% [markdown]
# ### Anatomy of a Matplotlib figure

# %% [markdown]
# ![](matplotlib-anatomy-of-a-plot.png)

# %% [markdown]
# **Matplotlib** is built on NumPy arrays. It integrate directly with Pandas.

# %%
# Create a plot (x, y)
plt.plot()
# Out:
# []

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

plt.plot(x, y)

# %% [markdown]
# There are 2 ways to plot in Matplotlib. The first way shown below is called **stateless** way of plotting. The other plotting method is called **stateful**.
#
# Note from [Matplotlib's documentation](https://matplotlib.org/stable/tutorials/introductory/pyplot.html#sphx-glr-tutorials-introductory-pyplot-py):
#
# ```
# Note: the pyplot API is generally less-flexible than the object-oriented API. Most of the function calls you see here can also be called as methods from an Axes object. We recommend browsing the tutorials and examples to see how this works. In general, try to use the object-oriented interface over the pyplot interface.
# ```

# %%
# First method
# Create a figure
fig = plt.figure() 

# Add axes
ax = fig.add_subplot()

plt.show()

# %%
# Second method
# Create a figure
fig = plt.figure()

# Add axes
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y)
plt.show()

# %%
# Third method (recommended)
# Create a figure and a set of subplots
fig, ax = plt.subplots()
ax.plot(x, y)

# %% [markdown]
# ### Matplotlib example workflow

# %%
# Step 0. Import matplotlib
# %matplotlib inline
# import matplotlib.pyplot as plt

# %%
# Step 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# %%
# Step 2. Setup plot
# figsize=(width, height)
fig, ax = plt.subplots(figsize=(10, 10)) 

# Step 3. Plot data
ax.plot(x, y)

# Step 4. Customize plot
ax.set(title="Example plot using OOP", xlabel="X-axis", ylabel="Y-axis")

# Step 5. Save the whole figure
fig.savefig("matplotlib-images/sample-plot.png")

# %% [markdown]
# ### Making figures with NumPy arrays

# %% [markdown]
# ### Creating a line plot

# %%
# Create some data
x = np.linspace(0, 10, 100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
# Plot the data
fig, ax = plt.subplots()
ax.plot(x, x**2)

# %% [markdown]
# The default plot in Matplotlib is a line plot.

# %% [markdown]
# ### Creating a scatter plot

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %% [markdown]
# ### Creating a bar plot

# %%
# Make a plot from dictionary
nut_butter_prices = {"Almond butter": 10, "Peanut butter": 8, "Cashew butter": 12}

fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Nut butter prices", ylabel="Price in USD")
# Out:
# [Text(0.5, 1.0, 'Nut butter prices'), Text(0, 0.5, 'Price in USD')]

# %%
# Horizontal bar plot
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set(title="Scores by group and gender", ylabel="Scores")
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %% [markdown]
# ### Creating a histogram plot

# %%
# Create data
x = np.random.randn(1000)

# %%
# Create figure
fig, ax = plt.subplots()
ax.hist(x)
# Out:
# (array([ 11.,  46.,  81., 179., 206., 229., 149.,  60.,  26.,  13.]),
#  array([-2.92683912, -2.32849748, -1.73015583, -1.13181419, -0.53347254,
#          0.0648691 ,  0.66321075,  1.26155239,  1.85989404,  2.45823568,
#          3.05657733]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Two options for subplot

# %%
# Subplot option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

# Plot to each different axis
ax1.plot(x, x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(1000))
# Out:
# (array([  2.,   6.,  39., 141., 193., 280., 201.,  95.,  36.,   7.]),
#  array([-3.68579559, -3.01236177, -2.33892795, -1.66549413, -0.9920603 ,
#         -0.31862648,  0.35480734,  1.02824116,  1.70167499,  2.37510881,
#          3.04854263]),
#  <BarContainer object of 10 artists>)

# %%
# Subplot option 2
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

# Plot to each different index
ax[0, 0].plot(x, x/2)
ax[0, 1].scatter(np.random.random(10), np.random.random(10))
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1, 1].hist(np.random.randn(1000))
# Out:
# (array([  2.,  39.,  67., 147., 214., 201., 187.,  94.,  31.,  18.]),
#  array([-2.95202689, -2.38611463, -1.82020237, -1.25429012, -0.68837786,
#         -0.1224656 ,  0.44344665,  1.00935891,  1.57527117,  2.14118343,
#          2.70709568]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Plotting from Pandas DataFrame

# %%
# Make a DataFrame
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2020", periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Price"] = car_sales["Price"].str.replace("[\$\,\.]", "")
car_sales
# Out:
# C:\Users\CEDRIC~1\AppData\Local\Temp/ipykernel_3472/3073007673.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace("[\$\,\.]", "")
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# Remove last two zeros
car_sales["Price"] = car_sales["Price"].str[:-2]

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2020", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
# Plot total sales
car_sales.plot(x="Sale Date", y="Total Sales")
# Out:
# <AxesSubplot:xlabel='Sale Date'>

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %%
# Bar graph from DataFrame
x = np.random.rand(10, 4)

df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.065713  0.840689  0.310792  0.588900
# 1  0.210920  0.670960  0.328253  0.568523
# 2  0.831152  0.967810  0.818794  0.787584
# 3  0.708019  0.088434  0.139306  0.077819
# 4  0.282950  0.389332  0.464418  0.250686
# 5  0.495499  0.779880  0.167762  0.037069
# 6  0.897501  0.787882  0.949975  0.662755
# 7  0.007973  0.282390  0.105805  0.629968
# 8  0.357195  0.279969  0.429565  0.850359
# 9  0.434920  0.796765  0.343047  0.852585

# %%
df.plot.bar()
# or df.plot(kind="bar")
# df.plot() is preferred since you can specify your visualization in one line if 
# your DataFrame has more than 2 columns
# Out:
# <AxesSubplot:>

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar")
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
car_sales["Odometer (KM)"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
heart_disease = pd.read_csv("heart-disease.csv")

# %%
# Create a histogram
heart_diseas["age"].plot(kind="hist", bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot(kind="hist", figsize=(10, 30), subplots=True)
# Out:
# array([<AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>],
#       dtype=object)

# %% [markdown]
# ### Pyplot vs Matplotlib OO method
# The documentation will always encourage you to use Matplotlib's OO method.
#
# When plotting something quickly, it's okay to use pyplot.
# When plotting something more advanced, use the OO method.

# %%
over_50 = heart_disease[heart_disease["age"] > 50]

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Pyplot method
over_50.plot(kind="scatter", x="age", y="chol", c="target")
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
# Matplotlib OO method with pyplot
fig, ax = plt.subplots(figsize=(10, 6));
over_50.plot(kind="scatter", x="age", y="chol", c="target", ax=ax)
ax.set_xlim([45, 100])
# Out:
# (45.0, 100.0)

# %%
# Matplotlib OO method from scratch
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(x=over_50["age"], y=over_50["chol"], c=over_50["target"])

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels", xlabel="Age", ylabel="Cholesterol")
ax.legend(*scatter.legend_elements(), title="Target")
ax.axhline(over_50["chol"].mean(), linestyle="--", c="green")

# %%
# Subplot
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, figsize=(10, 10), sharex=True)

# Add data to ax0
scatter = ax0.scatter(x=over_50["age"], y=over_50["chol"], c=over_50["target"])

# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels", ylabel="Cholesterol Level")
ax0.legend(*scatter.legend_elements(), title="Target")
ax0.axhline(y=over_50["chol"].mean(), linestyle="--", c="green")

# Add data to ax1
scatter1 = ax1.scatter(x=over_50["age"], y=over_50["thalach"], c=over_50["target"])

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate", xlabel="Age", ylabel="Max Heart Rate")
ax1.legend(*scatter1.legend_elements(), title="Target")
ax1.axhline(y=over_50["thalach"].mean(), linestyle="--", c="orange")

# Add title to whole figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %% [markdown]
# ### Customizing matplotlib plots

# %%
# Display different styles
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500

# %%
car_sales["Price"] = car_sales["Price"].astype(int)

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
# Usually ran along with imports
plt.style.use("seaborn-whitegrid")

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %% [markdown]
# The keyword argument `cmap` can be used to change the color scheme or color map of the plot.
#
# For further information see [Matplotlib's documentation on colormap](https://matplotlib.org/3.5.0/tutorials/colors/colormaps.html)

# %%
plt.style.use("seaborn-whitegrid")

# OO method from scratch
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(x=over_50["age"], y=over_50["chol"], c=over_50["target"], cmap="summer")

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels", xlabel="Age", ylabel="Cholesterol")
ax.legend(*scatter.legend_elements(), title="Target")
ax.axhline(over_50["chol"].mean(), linestyle="--", c="crimson")

# %%
# Customizing the x and y axis limitations

# Subplot
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, figsize=(10, 10), sharex=True)

# Add data to ax0
scatter = ax0.scatter(x=over_50["age"], y=over_50["chol"], c=over_50["target"], cmap="winter")

# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels", ylabel="Cholesterol Level")
ax0.set_xlim([50, 80])
ax0.legend(*scatter.legend_elements(), title="Target")
ax0.axhline(y=over_50["chol"].mean(), linestyle="--", c="green")

# Add data to ax1
scatter1 = ax1.scatter(x=over_50["age"], y=over_50["thalach"], c=over_50["target"], cmap="summer")

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate", xlabel="Age", ylabel="Max Heart Rate")
ax1.set_xlim([50, 80])
ax1.set_ylim([60, 200])
ax1.legend(*scatter1.legend_elements(), title="Target")
ax1.axhline(y=over_50["thalach"].mean(), linestyle="--", c="orange")

# Add title to whole figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %% [markdown]
# ### Saving/exporting your figures

# %%
# fig.savefig("heart-disease-analysis-plot-saved-with-code.png")
